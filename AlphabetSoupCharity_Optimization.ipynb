# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import seaborn as sns

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
drop_cols = ['EIN', 'NAME']
application_df.drop(drop_cols, axis=1, inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
counts = pd.DataFrame(application_df.value_counts('APPLICATION_TYPE'))
counts
# Out:
#                       0
# APPLICATION_TYPE
# T3                27037
# T4                 1542
# T6                 1216
# T5                 1173
# T19                1065
# T8                  737
# T7                  725
# T10                 528
# T9                  156
# T13                  66
# T12                  27
# T2                   16
# T14                   3
# T25                   3
# T29                   2
# T15                   2
# T17                   1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

application_types_to_replace = []
cutoff = 200
for i in range(len(counts)):
    if counts.iloc[i,0] < cutoff:
        application_types_to_replace.append(counts.index[i])
        
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
class_counts = pd.DataFrame(application_df['CLASSIFICATION'].value_counts())
class_counts
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# ...               ...
# C4120               1
# C8210               1
# C2561               1
# C4500               1
# C2150               1
#
# [71 rows x 1 columns]

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE

classifications_to_replace = []
cutoff = 1000
for i in range(len(class_counts)):
    if class_counts.iloc[i,0] < cutoff:
        classifications_to_replace.append(class_counts.index[i])

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
application_df = pd.get_dummies(application_df, drop_first=True) #Try dropping the correlated columns
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  ORGANIZATION_Trust  \
# 0                    0                    0  ...                   0
# 1                    0                    0  ...                   0
# 2                    0                    0  ...                   0
# 3                    0                    0  ...                   1
# 4                    0                    0  ...                   1
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  0                       0                         0
# 1                  1                       0                         0
# 2                  0                       0                         0
# 3                  0                       1                         0
# 4                  0                       0                         1
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   0                 0                       0
# 1                   0                 0                       0
# 2                   0                 0                       0
# 3                   0                 0                       0
# 4                   0                 0                       0
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_Y
# 0                0                  0                         0
# 1                0                  0                         0
# 2                0                  0                         0
# 3                0                  0                         0
# 4                0                  0                         0
#
# [5 rows x 37 columns]

# %%
application_df.drop(application_df[application_df.ASK_AMT > 1000000].index, inplace=True) #Getting rid of ASK_AMT's larger than $1000000

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = application_df['IS_SUCCESSFUL']
X = application_df.drop(columns='IS_SUCCESSFUL')
y.value_counts()
# Out:
# 1    17557
# 0    15165
# Name: IS_SUCCESSFUL, dtype: int64

# %%
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

scaler.fit(X_train[['ASK_AMT']]) #Fitting the scaler object using JUST the training data

X_train_scaled = scaler.transform(X_train[["ASK_AMT"]]) #Now, transforming the training and testing dataset using the scaler object
X_test_scaled = scaler.transform(X_test[["ASK_AMT"]])

X_train['ASK_AMT'] = X_train_scaled
X_test['ASK_AMT'] = X_test_scaled

# %%
X_train['ASK_AMT'].describe() #Checking to make sure the mean is 0 and STD is 1
# Out:
# count    2.454100e+04
# mean    -2.518936e-17
# std      1.000020e+00
# min     -2.923162e-01
# 25%     -2.923162e-01
# 50%     -2.923162e-01
# 75%     -2.923162e-01
# max      8.197614e+00
# Name: ASK_AMT, dtype: float64

# %%
import matplotlib.pyplot as plt
sns.histplot(X_train, x='ASK_AMT', bins=100) #Looking at a histogram of the ASK_AMT column to see if there are outliers
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %%
#Converting dataframes into arrays so they are compatible with the sklearn .fit function
X_train = X_train.values
X_test = X_test.values

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               3700
#
#  dense_1 (Dense)             (None, 30)                3030
#
#  dense_2 (Dense)             (None, 10)                310
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 7051 (27.54 KB)
# Trainable params: 7051 (27.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 767/767 [==============================] - 1s 860us/step - loss: 0.5677 - accuracy: 0.7253
# Epoch 2/100
# 767/767 [==============================] - 1s 814us/step - loss: 0.5507 - accuracy: 0.7353
# Epoch 3/100
# 767/767 [==============================] - 1s 834us/step - loss: 0.5478 - accuracy: 0.7369
# Epoch 4/100
# 767/767 [==============================] - 1s 830us/step - loss: 0.5456 - accuracy: 0.7382
# Epoch 5/100
# 767/767 [==============================] - 1s 985us/step - loss: 0.5441 - accuracy: 0.7370
# Epoch 6/100
# 767/767 [==============================] - 1s 916us/step - loss: 0.5431 - accuracy: 0.7375
# Epoch 7/100
# 767/767 [==============================] - 1s 901us/step - loss: 0.5424 - accuracy: 0.7390
# Epoch 8/100
# 767/767 [==============================] - 1s 834us/step - loss: 0.5413 - accuracy: 0.7388
# Epoch 9/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7395
# Epoch 10/100
# 767/767 [==============================] - 1s 833us/step - loss: 0.5404 - accuracy: 0.7394
# Epoch 11/100
# 767/767 [==============================] - 1s 825us/step - loss: 0.5393 - accuracy: 0.7410
# Epoch 12/100
# 767/767 [==============================] - 1s 851us/step - loss: 0.5390 - accuracy: 0.7409
# Epoch 13/100
# 767/767 [==============================] - 1s 837us/step - loss: 0.5384 - accuracy: 0.7397
# Epoch 14/100
# 767/767 [==============================] - 1s 814us/step - loss: 0.5383 - accuracy: 0.7418
# Epoch 15/100
# 767/767 [==============================] - 1s 814us/step - loss: 0.5376 - accuracy: 0.7411
# Epoch 16/100
# 767/767 [==============================] - 1s 815us/step - loss: 0.5373 - accuracy: 0.7418
# Epoch 17/100
# 767/767 [==============================] - 1s 952us/step - loss: 0.5367 - accuracy: 0.7410
# Epoch 18/100
# 767/767 [==============================] - 1s 936us/step - loss: 0.5362 - accuracy: 0.7423
# Epoch 19/100
# 767/767 [==============================] - 1s 926us/step - loss: 0.5362 - accuracy: 0.7421
# Epoch 20/100
# 767/767 [==============================] - 1s 938us/step - loss: 0.5354 - accuracy: 0.7423
# Epoch 21/100
# 767/767 [==============================] - 1s 821us/step - loss: 0.5348 - accuracy: 0.7426
# Epoch 22/100
# 767/767 [==============================] - 1s 845us/step - loss: 0.5348 - accuracy: 0.7426
# Epoch 23/100
# 767/767 [==============================] - 1s 927us/step - loss: 0.5343 - accuracy: 0.7426
# Epoch 24/100
# 767/767 [==============================] - 1s 838us/step - loss: 0.5340 - accuracy: 0.7434
# Epoch 25/100
# 767/767 [==============================] - 1s 912us/step - loss: 0.5336 - accuracy: 0.7437
# Epoch 26/100
# 767/767 [==============================] - 1s 973us/step - loss: 0.5334 - accuracy: 0.7429
# Epoch 27/100
# 767/767 [==============================] - 1s 913us/step - loss: 0.5330 - accuracy: 0.7428
# Epoch 28/100
# 767/767 [==============================] - 1s 839us/step - loss: 0.5328 - accuracy: 0.7437
# Epoch 29/100
# 767/767 [==============================] - 1s 889us/step - loss: 0.5323 - accuracy: 0.7445
# Epoch 30/100
# 767/767 [==============================] - 1s 840us/step - loss: 0.5321 - accuracy: 0.7443
# Epoch 31/100
# 767/767 [==============================] - 1s 869us/step - loss: 0.5320 - accuracy: 0.7436
# Epoch 32/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7443
# Epoch 33/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7443
# Epoch 34/100
# 767/767 [==============================] - 1s 883us/step - loss: 0.5312 - accuracy: 0.7450
# Epoch 35/100
# 767/767 [==============================] - 1s 809us/step - loss: 0.5306 - accuracy: 0.7446
# Epoch 36/100
# 767/767 [==============================] - 1s 827us/step - loss: 0.5308 - accuracy: 0.7445
# Epoch 37/100
# 767/767 [==============================] - 1s 966us/step - loss: 0.5307 - accuracy: 0.7448
# Epoch 38/100
# 767/767 [==============================] - 1s 812us/step - loss: 0.5302 - accuracy: 0.7447
# Epoch 39/100
# 767/767 [==============================] - 1s 868us/step - loss: 0.5298 - accuracy: 0.7457
# Epoch 40/100
# 767/767 [==============================] - 1s 971us/step - loss: 0.5294 - accuracy: 0.7457
# Epoch 41/100
# 767/767 [==============================] - 1s 933us/step - loss: 0.5292 - accuracy: 0.7451
# Epoch 42/100
# 767/767 [==============================] - 1s 926us/step - loss: 0.5293 - accuracy: 0.7452
# Epoch 43/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5293 - accuracy: 0.7453
# Epoch 44/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5290 - accuracy: 0.7461
# Epoch 45/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7464
# Epoch 46/100
# 767/767 [==============================] - 1s 905us/step - loss: 0.5286 - accuracy: 0.7469
# Epoch 47/100
# 767/767 [==============================] - 1s 826us/step - loss: 0.5285 - accuracy: 0.7466
# Epoch 48/100
# 767/767 [==============================] - 1s 834us/step - loss: 0.5282 - accuracy: 0.7466
# Epoch 49/100
# 767/767 [==============================] - 1s 813us/step - loss: 0.5282 - accuracy: 0.7458
# Epoch 50/100
# 767/767 [==============================] - 1s 812us/step - loss: 0.5277 - accuracy: 0.7470
# Epoch 51/100
# 767/767 [==============================] - 1s 895us/step - loss: 0.5282 - accuracy: 0.7463
# Epoch 52/100
# 767/767 [==============================] - 1s 832us/step - loss: 0.5275 - accuracy: 0.7467
# Epoch 53/100
# 767/767 [==============================] - 1s 811us/step - loss: 0.5276 - accuracy: 0.7476
# Epoch 54/100
# 767/767 [==============================] - 1s 908us/step - loss: 0.5269 - accuracy: 0.7465
# Epoch 55/100
# 767/767 [==============================] - 1s 891us/step - loss: 0.5276 - accuracy: 0.7468
# Epoch 56/100
# 767/767 [==============================] - 1s 856us/step - loss: 0.5265 - accuracy: 0.7467
# Epoch 57/100
# 767/767 [==============================] - 1s 830us/step - loss: 0.5270 - accuracy: 0.7455
# Epoch 58/100
# 767/767 [==============================] - 1s 804us/step - loss: 0.5264 - accuracy: 0.7451
# Epoch 59/100
# 767/767 [==============================] - 1s 805us/step - loss: 0.5265 - accuracy: 0.7461
# Epoch 60/100
# 767/767 [==============================] - 1s 815us/step - loss: 0.5259 - accuracy: 0.7465
# Epoch 61/100
# 767/767 [==============================] - 1s 875us/step - loss: 0.5263 - accuracy: 0.7467
# Epoch 62/100
# 767/767 [==============================] - 1s 845us/step - loss: 0.5258 - accuracy: 0.7457
# Epoch 63/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5258 - accuracy: 0.7463
# Epoch 64/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5259 - accuracy: 0.7477
# Epoch 65/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.5255 - accuracy: 0.7463
# Epoch 66/100
# 767/767 [==============================] - 1s 981us/step - loss: 0.5254 - accuracy: 0.7477
# Epoch 67/100
# 767/767 [==============================] - 1s 843us/step - loss: 0.5251 - accuracy: 0.7476
# Epoch 68/100
# 767/767 [==============================] - 1s 837us/step - loss: 0.5249 - accuracy: 0.7470
# Epoch 69/100
# 767/767 [==============================] - 1s 922us/step - loss: 0.5248 - accuracy: 0.7475
# Epoch 70/100
# 767/767 [==============================] - 1s 883us/step - loss: 0.5249 - accuracy: 0.7466
# Epoch 71/100
# 767/767 [==============================] - 1s 814us/step - loss: 0.5243 - accuracy: 0.7465
# Epoch 72/100
# 767/767 [==============================] - 1s 816us/step - loss: 0.5246 - accuracy: 0.7474
# Epoch 73/100
# 767/767 [==============================] - 1s 817us/step - loss: 0.5238 - accuracy: 0.7472
# Epoch 74/100
# 767/767 [==============================] - 1s 799us/step - loss: 0.5247 - accuracy: 0.7482
# Epoch 75/100
# 767/767 [==============================] - 1s 801us/step - loss: 0.5242 - accuracy: 0.7475
# Epoch 76/100
# 767/767 [==============================] - 1s 789us/step - loss: 0.5242 - accuracy: 0.7485
# Epoch 77/100
# 767/767 [==============================] - 1s 826us/step - loss: 0.5236 - accuracy: 0.7472
# Epoch 78/100
# 767/767 [==============================] - 1s 811us/step - loss: 0.5238 - accuracy: 0.7484
# Epoch 79/100
# 767/767 [==============================] - 1s 802us/step - loss: 0.5237 - accuracy: 0.7481
# Epoch 80/100
# 767/767 [==============================] - 1s 809us/step - loss: 0.5235 - accuracy: 0.7477
# Epoch 81/100
# 767/767 [==============================] - 1s 806us/step - loss: 0.5236 - accuracy: 0.7485
# Epoch 82/100
# 767/767 [==============================] - 1s 809us/step - loss: 0.5235 - accuracy: 0.7479
# Epoch 83/100
# 767/767 [==============================] - 1s 818us/step - loss: 0.5237 - accuracy: 0.7493
# Epoch 84/100
# 767/767 [==============================] - 1s 846us/step - loss: 0.5232 - accuracy: 0.7483
# Epoch 85/100
# 767/767 [==============================] - 1s 804us/step - loss: 0.5233 - accuracy: 0.7476
# Epoch 86/100
# 767/767 [==============================] - 1s 801us/step - loss: 0.5233 - accuracy: 0.7481
# Epoch 87/100
# 767/767 [==============================] - 1s 836us/step - loss: 0.5231 - accuracy: 0.7481
# Epoch 88/100
# 767/767 [==============================] - 1s 894us/step - loss: 0.5230 - accuracy: 0.7482
# Epoch 89/100
# 767/767 [==============================] - 1s 938us/step - loss: 0.5224 - accuracy: 0.7486
# Epoch 90/100
# 767/767 [==============================] - 1s 904us/step - loss: 0.5232 - accuracy: 0.7478
# Epoch 91/100
# 767/767 [==============================] - 1s 872us/step - loss: 0.5222 - accuracy: 0.7488
# Epoch 92/100
# 767/767 [==============================] - 1s 824us/step - loss: 0.5228 - accuracy: 0.7485
# Epoch 93/100
# 767/767 [==============================] - 1s 877us/step - loss: 0.5224 - accuracy: 0.7486
# Epoch 94/100
# 767/767 [==============================] - 1s 902us/step - loss: 0.5223 - accuracy: 0.7482
# Epoch 95/100
# 767/767 [==============================] - 1s 806us/step - loss: 0.5222 - accuracy: 0.7484
# Epoch 96/100
# 767/767 [==============================] - 1s 840us/step - loss: 0.5222 - accuracy: 0.7483
# Epoch 97/100
# 767/767 [==============================] - 1s 804us/step - loss: 0.5217 - accuracy: 0.7491
# Epoch 98/100
# 767/767 [==============================] - 1s 821us/step - loss: 0.5217 - accuracy: 0.7492
# Epoch 99/100
# 767/767 [==============================] - 1s 810us/step - loss: 0.5221 - accuracy: 0.7484
# Epoch 100/100
# 767/767 [==============================] - 1s 804us/step - loss: 0.5215 - accuracy: 0.7493

# %%
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 256/256 - 1s - loss: 0.5665 - accuracy: 0.7385 - 539ms/epoch - 2ms/step
# Loss: 0.5665063858032227, Accuracy: 0.738540530204773

# %%
#This performance is slightly better than with the first model. I will stick with dropping the colinear columns in the encoding stage.

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('AlphabetSoupCharity_Optimization.h5')
# Out:
# C:\Users\gmich\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
